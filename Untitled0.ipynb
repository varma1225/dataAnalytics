# %% [markdown]
# <a href="https://colab.research.google.com/github/varma1225/dataAnalytics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/vijayuv/onlineretail")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle username:Your Kaggle Key:
# ---------------------------------------------------------------------------
# Abort                                     Traceback (most recent call last)
# <ipython-input-11-afa681d20b32> in <cell line: 0>()
#       1 import opendatasets as od
# ----> 2 od.download("https://www.kaggle.com/datasets/vijayuv/onlineretail")
#
# /usr/local/lib/python3.11/dist-packages/opendatasets/__init__.py in download(dataset_id_or_url, data_dir, force, dry_run, **kwargs)
#      11     # Check for a Kaggle dataset URL
#      12     if is_kaggle_url(dataset_id_or_url):
# ---> 13         return download_kaggle_dataset(dataset_id_or_url, data_dir=data_dir, force=force, dry_run=dry_run)
#      14
#      15     # Check for Google Drive URL
#
# ...

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/vijayuv/onlineretail")
# Out:
# Skipping, found downloaded files in "./onlineretail" (use force=True to force download)

# %%
import pandas as pd
df=pd.read_csv("/content/OnlineRetail.csv.zip")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-153246da4985> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("/content/OnlineRetail.csv.zip")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas  as pd
od.download("https://www.kaggle.com/datasets/vijayuv/onlineretail")
# Out:
# Skipping, found downloaded files in "./onlineretail" (use force=True to force download)

# %%
 data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# prompt: checking the missing values & if there are some duplicate roes or not

# Check for missing values
print(data.isnull().sum())

# Check for duplicate rows
print(data.duplicated().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
# 5268

# %%
data.dropna()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.drop_dupliates
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-b340c3dab1b8> in <cell line: 0>()
# ----> 1 data.drop_dupliates
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'drop_dupliates'

# %%
data.drop_duplicates()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# prompt: handling missing values

# Remove rows with missing values
data.dropna(inplace=True)

# Remove duplicate rows
data.drop_duplicates(inplace=True)

# Verify changes (optional)
print(data.isnull().sum())
print(data.duplicated().sum())
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64
# 0

# %%
# prompt: plot the distribution of discrete values quality description and country

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame after cleaning
# If not, replace 'data' with your DataFrame variable name

# Plot the distribution of 'Description'
plt.figure(figsize=(12, 6))
sns.countplot(x='Description', data=data, order=data['Description'].value_counts().index[:20]) # Top 20 descriptions for clarity
plt.xticks(rotation=90)
plt.title('Distribution of Product Descriptions')
plt.xlabel('Product Description')
plt.ylabel('Count')
plt.show()

# Plot the distribution of 'Country'
plt.figure(figsize=(12, 6))
sns.countplot(x='Country', data=data, order=data['Country'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Distribution of Customers by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %%
# prompt: identify the most frequently purchased product category

# Assuming 'data' is your DataFrame after cleaning
# If not, replace 'data' with your DataFrame variable name

# Convert 'Description' to string type if it's not already
data['Description'] = data['Description'].astype(str)

# Extract the first word from the 'Description' column
data['Product_Category'] = data['Description'].str.split().str[0]

# Calculate the frequency of each product category
category_counts = data['Product_Category'].value_counts()

# Find the most frequent product category
most_frequent_category = category_counts.index[0]

print(f"The most frequently purchased product category is: {most_frequent_category}")
# Out:
# The most frequently purchased product category is: SET

# %%
# prompt: find the country contributing most sales

# Calculate total sales for each country
country_sales = data.groupby('Country')['Quantity'].sum()

# Find the country with the highest total sales
country_with_most_sales = country_sales.idxmax()

print(f"The country with the most sales is: {country_with_most_sales}")
# Out:
# The country with the most sales is: United Kingdom

# %%
# prompt: convert the order data column to a datetime format

import pandas as pd

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Convert 'InvoiceDate' column to datetime format
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
# prompt: create new colmatttumns like day of the week andd day of the month ,month ,year,

# Assuming 'data' is your DataFrame and 'InvoiceDate' column is already in datetime format
# If not, uncomment and adjust the following line:
# data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

data['DayOfWeek'] = data['InvoiceDate'].dt.dayofweek  # Monday=0, Sunday=6
data['DayOfMonth'] = data['InvoiceDate'].dt.day
data['Month'] = data['InvoiceDate'].dt.month
data['Year'] = data['InvoiceDate'].dt.year

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country Product_Category  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom            WHITE
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom            WHITE
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom            CREAM
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          KNITTED
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom              RED
#
#    DayOfWeek  DayOfMonth  Month  Year
# 0          2           1     12  2010
# ...

# %%
# prompt: set the order data column as the DataFrame index

# Assuming 'data' is your DataFrame and 'InvoiceDate' column is already in datetime format
# If not, uncomment and adjust the following line:
# data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

data['DayOfWeek'] = data['InvoiceDate'].dt.dayofweek  # Monday=0, Sunday=6
data['DayOfMonth'] = data['InvoiceDate'].dt.day
data['Month'] = data['InvoiceDate'].dt.month
data['Year'] = data['InvoiceDate'].dt.year

# Set 'InvoiceDate' as the index
data = data.set_index('InvoiceDate')

data.head()
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#                      Quantity  UnitPrice  CustomerID         Country  \
# InvoiceDate
# 2010-12-01 08:26:00         6       2.55     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         8       2.75     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
#
# ...

# %%
# prompt: compute the matrix correlation for numerical columns

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Select only numerical columns for correlation analysis
numerical_cols = data.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_cols.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#             Quantity  UnitPrice  CustomerID  DayOfWeek  DayOfMonth     Month  \
# Quantity    1.000000  -0.001243   -0.003457  -0.004750   -0.000237 -0.002354
# UnitPrice  -0.001243   1.000000   -0.004524  -0.002964   -0.001911 -0.003140
# CustomerID -0.003457  -0.004524    1.000000   0.020804   -0.001930  0.029855
# DayOfWeek  -0.004750  -0.002964    0.020804   1.000000   -0.005307  0.025144
# DayOfMonth -0.000237  -0.001911   -0.001930  -0.005307    1.000000 -0.117818
# Month      -0.002354  -0.003140    0.029855   0.025144   -0.117818  1.000000
# Year        0.001041   0.000978   -0.035279  -0.016204    0.166678 -0.341560
#
#                 Year
# Quantity    0.001041
# UnitPrice   0.000978
# CustomerID -0.035279
# DayOfWeek  -0.016204
# DayOfMonth  0.166678
# Month      -0.341560
# Year        1.000000

# %%
# prompt: visualize the correlation matrix for numerical columns

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame and 'InvoiceDate' column is already in datetime format
# If not, uncomment and adjust the following line:
# data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

data['DayOfWeek'] = data['InvoiceDate'].dt.dayofweek  # Monday=0, Sunday=6
data['DayOfMonth'] = data['InvoiceDate'].dt.day
data['Month'] = data['InvoiceDate'].dt.month
data['Year'] = data['InvoiceDate'].dt.year

# Set 'InvoiceDate' as the index
data = data.set_index('InvoiceDate')

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Select only numerical columns for correlation analysis
numerical_cols = data.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_cols.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'InvoiceDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-032bef506ef2> in <cell line: 0>()
#       8 # data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
# ...

# %%
# prompt: visualize the correlation matrix for numerical columns

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame and 'InvoiceDate' was previously set as index

# You don't need to re-create the date-related columns here
# because they were already created in a previous cell.
# Just access them directly using data['DayOfWeek'], data['DayOfMonth'], etc.

# If for some reason these columns are missing, you can recreate them:
# data['DayOfWeek'] = data.index.dayofweek  # Accessing dayofweek

# %%
# prompt: visualize the correlation matrix for numerical columns

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame and 'InvoiceDate' was previously set as index

# You don't need to re-create the date-related columns here
# because they were already created in a previous cell.
# Just access them directly using data['DayOfWeek'], data['DayOfMonth'], etc.

# If for some reason these columns are missing, you can recreate them:
# data['DayOfWeek'] = data.index.dayofweek  # Accessing dayofweek from the index
# data['DayOfMonth'] = data.index.day
# data['Month'] = data.index.month
# data['Year'] = data.index.year

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Select only numerical columns for correlation analysis
numerical_cols = data.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_cols.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
# prompt: visualize the correlation matrix using a heatmap

# Assuming 'data' is your DataFrame and 'InvoiceDate' was previously set as index

# You don't need to re-create the date-related columns here
# because they were already created in a previous cell.
# Just access them directly using data['DayOfWeek'], data['DayOfMonth'], etc.

# If for some reason these columns are missing, you can recreate them:
# data['DayOfWeek'] = data.index.dayofweek  # Accessing dayofweek from the index
# data['DayOfMonth'] = data.index.day
# data['Month'] = data.index.month
# data['Year'] = data.index.year

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Select only numerical columns for correlation analysis
numerical_cols = data.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_cols.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
# prompt: use loc to extract sales data for  specific data or range of dates

# Assuming 'data' is your DataFrame and 'InvoiceDate' is the index (datetime)
# Example: Extract sales data for December 2011

december_2011_sales = data.loc['2011-12-01':'2011-12-31']
print(december_2011_sales)

# Example: Extract sales data for a specific date
specific_date_sales = data.loc['2010-12-01']  # Replace '2010-12-01' with your desired date
print(specific_date_sales)

# Example: Extract sales data for a range of dates
date_range_sales = data.loc['2011-01-01':'2011-01-10']
date_range_sales
# Out:
#                     InvoiceNo StockCode                         Description  \
# InvoiceDate
# 2011-12-01 08:12:00   C579889     23245          SET OF 3 REGENCY CAKE TINS
# 2011-12-01 08:14:00   C579890     84947   ANTIQUE SILVER TEA GLASS ENGRAVED
# 2011-12-01 08:14:00   C579890     23374             RED SPOT PAPER GIFT BAG
# 2011-12-01 08:14:00   C579890     84945  MULTI COLOUR SILVER T-LIGHT HOLDER
# 2011-12-01 08:18:00   C579891     23485       BOTANICAL GARDENS WALL CLOCK
# ...                       ...       ...                                 ...
# 2011-12-09 12:50:00    581587     22613         PACK OF 20 SPACEBOY NAPKINS
# 2011-12-09 12:50:00    581587     22899        CHILDREN'S APRON DOLLY GIRL
# 2011-12-09 12:50:00    581587     23254       CHILDRENS CUTLERY DOLLY GIRL
# 2011-12-09 12:50:00    581587     23255     CHILDRENS CUTLERY CIRCUS PARADE
# 2011-12-09 12:50:00    581587     22138       BAKING SET 9 PIECE RETROSPOT
#
# ...

# %%
# prompt: use iloc to extract the first 10 rows of the dataset

# Assuming 'data' is your DataFrame. Replace with your actual DataFrame name if needed.
first_10_rows = data.iloc[:10]
first_10_rows
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 2010-12-01 08:26:00    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 2010-12-01 08:26:00    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 2010-12-01 08:28:00    536366     22633               HAND WARMER UNION JACK
# 2010-12-01 08:28:00    536366     22632            HAND WARMER RED POLKA DOT
# 2010-12-01 08:34:00    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
#
#                      Quantity  UnitPrice  CustomerID         Country  \
# InvoiceDate
# ...

# %%
# prompt: Using dataframe first_10_rows: suggest a plot

import altair as alt

# Create a bar chart showing the quantity of each product sold
alt.Chart(first_10_rows).mark_bar().encode(
    x='Description',
    y='Quantity'
).properties(
    title='Quantity of Products Sold'
)
# Out:
# alt.Chart(...)

# %%
# prompt: drop a coloumn e.g country   using drop

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Drop the 'Country' column
data = data.drop('Country', axis=1)

# Now 'data' DataFrame no longer has the 'Country' column

# %%
# prompt: drop a column( e.g country )  using drop (axis=1)

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Drop the 'Country' column
data = data.drop('Country', axis=1)

# Now 'data' DataFrame no longer has the 'Country' column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-09eb76994e76> in <cell line: 0>()
#       5
#       6 # Drop the 'Country' column
# ----> 7 data = data.drop('Country', axis=1)
#       8
#       9 # Now 'data' DataFrame no longer has the 'Country' column
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
# prompt: drop a column( e.g country )  using drop (axis=1)

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Check if 'Country' column exists before dropping
if 'Country' in data.columns:
    data = data.drop('Country', axis=1)
    print("'Country' column dropped successfully.")  # Optional confirmation message
else:
    print("'Country' column not found in DataFrame.")  # Optional message if column not found

# Now 'data' DataFrame no longer has the 'Country' column (if it existed)
# Out:
# 'Country' column not found in DataFrame.

# %%
# prompt: drop the first two rows using drop

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual name of your DataFrame variable if different

# Drop the first two rows
data = data.drop(index=data.index[:2])

# %%
# prompt: generrate a flow to the dataset

import opendatasets as od
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# ... (Your existing code for data loading and cleaning) ...

# Assuming 'data' is your cleaned DataFrame

# 1. Product Category Analysis
# (Your existing code for product category analysis)

# 2. Country Sales Analysis
# (Your existing code for country sales analysis)

# 3. Time Series Analysis
# Convert 'InvoiceDate' to datetime and set it as the index
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
data = data.set_index('InvoiceDate')

# Feature Engineering (day of week, day of month, month, year)
data['DayOfWeek'] = data.index.dayofweek
data['DayOfMonth'] = data.index.day
data['Month'] = data.index.month
data['Year'] = data.index.year


# 4. Correlation Analysis
numerical_cols = data.select_dtypes(include=['number'])
correlation_matrix = numerical_cols.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()


# 5. Time-based Data Exploration (e.g., sales by month)

monthly_sales = data.resample('M')['Quantity'].sum()
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales.index, monthly_sales.values)
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')
plt.title('Monthly Sales Trend')
plt.show()

# 6. Visualization with Altair (example using first 10 rows)
first_10_rows = data.iloc[:10]

alt.Chart(first_10_rows).mark_bar().encode(
    x='Description',
    y='Quantity'
).properties(
    title='Quantity of Products Sold (First 10 Rows)'
)

# 7. Data Cleaning: remove Country column
if 'Country' in data.columns:
  data = data.drop('Country', axis = 1)

# 8. Data Cleaning : remove first two rows
data = data.drop(index = data.index[:2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'InvoiceDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-d789a3aca11f> in <cell line: 0>()
#      19 # 3. Time Series Analysis
# ...

# %%
# prompt: generrate a flow to the dataset

import opendatasets as od
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# ... (Your existing code for data loading and cleaning) ...

# Assuming 'data' is your cleaned DataFrame

# 1. Product Category Analysis
# (Your existing code for product category

# %%
# prompt: generrate a flow to the dataset

import opendatasets as od
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# ... (Your existing code for data loading and cleaning) ...

# Assuming 'data' is your cleaned DataFrame

# 1. Product Category Analysis
# (Your existing code for product category analysis)

# 2. Country Sales Analysis
# (Your existing code for country sales analysis)

# 3. Time Series Analysis
# Check if 'InvoiceDate' is already the index
if 'InvoiceDate' not in data.columns:
    # If 'InvoiceDate' is not a column, it might already be the index
    # So, reset the index to bring it back as a column
    data = data.reset_index()

# Convert 'InvoiceDate' to datetime and set it as the index
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
data = data.set_index('InvoiceDate')

# Feature Engineering (day of week, day of month, month, year)
data['DayOfWeek'] = data.index.dayofweek
data['DayOfMonth'] = data.index.day
data['Month'] = data.index.month
data['Year'] = data.index.year


# 4. Correlation Analysis
numerical_cols = data.select_dtypes(include=['number'])
correlation_matrix = numerical_cols.corr()

plt.figure(figsize=(12, 10))
sns.
# Out:
#   File "<ipython-input-65-7e72d2d75496>", line 42
#     sns.
#         ^
# SyntaxError: invalid syntax

# %%
# prompt: generrate a flow to the dataset

import opendatasets as od
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# ... (Your existing code for data loading and cleaning) ...

# Assuming 'data' is your cleaned DataFrame

# 1. Product Category Analysis
# (Your existing code for product category analysis)

# 2. Country Sales Analysis
# (Your existing code for country sales analysis)

# 3. Time Series Analysis
# Check if 'InvoiceDate' is already the index
if 'InvoiceDate' not in data.columns:
    # If 'InvoiceDate' is not a column, it might already be the index
    # So, reset the index to bring it back as a column
    data = data.reset_index()

# Convert 'InvoiceDate' to datetime and set it as the index
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
data = data.set_index('InvoiceDate')

# Feature Engineering (day of week, day of month, month, year)
data['DayOfWeek'] = data.index.dayofweek
data['DayOfMonth'] = data.index.day
data['Month'] = data.index.month
data['Year'] = data.index.year


# 4. Correlation Analysis
numerical_cols = data.select_dtypes(include=['number'])
correlation_matrix = numerical_cols.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()


# 5. Time-based Data Exploration (e.g., sales by month)

monthly_sales = data.resample('M')['Quantity'].sum()
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales.index, monthly_sales.values)
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')
plt.title('Monthly Sales Trend')
plt.show()

# 6. Visualization with Altair (example using first 10 rows)
first_10_rows = data.iloc[:10]

alt.Chart(first_10_rows).mark_bar().encode(
    x='Description',
    y='Quantity'
).properties(
    title='Quantity of Products Sold (First 10 Rows)'
)

# 7. Data Cleaning: remove Country column
if 'Country' in data.columns:
  data = data.drop('Country', axis = 1)

# 8. Data Cleaning : remove first two rows
data = data.drop(index = data.index[:2])
# Out:
# <ipython-input-66-77bad9ba7b5d>:49: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = data.resample('M')['Quantity'].sum()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a74c58233b9e> in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
